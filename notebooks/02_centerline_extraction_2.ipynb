# %% [markdown]
# <a id="import"></a>
# # <p style="background-color:blue; font-family:calibri; color:white; font-size:200%; text-align:center; border-radius:20px 20px;">**Centerline Extraction: Method 2**</p>

# %% [markdown]
# Detailed explanation of the method that I am using to extract the centerline and from where I am grabbing the information.
# +++

# %%
# Imports

# %% [markdown]
# <a id="import"></a>
# # <p style="background-color:blue; font-family:calibri; color:white; font-size:120%; text-align:center; border-radius:20px 20px;">1.++++</p>
